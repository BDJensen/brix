-- %%
CREATE WIDGET TEXT schema_name DEFAULT "vessel";

-- %%
CREATE TABLE IF NOT EXISTS ${schema_name}.messages
USING DELTA LOCATION '/mnt/bd/openuniverselake/delta';

-- %%
drop TABLE IF  EXISTS ${schema_name}.messages

-- %% [markdown]
-- SELECT COUNT(DISTINCT `yyyy-mm-dd`) cnt_days /* 365 */, count(*) cnt /* 4.077.468.307 */
-- FROM $schema_name.messages;
