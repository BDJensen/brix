-- %%
CREATE WIDGET TEXT schema_name DEFAULT "vessel";

-- %%
CREATE TABLE IF NOT EXISTS ${schema_name}.messages
USING DELTA LOCATION '/mnt/bd/openuniverselake/aisraw/aisdata/delta';

-- %%
drop TABLE IF  EXISTS ${schema_name}.messages

-- %% [markdown]
-- SELECT COUNT(DISTINCT `yyyy-mm-dd`) cnt_days /* 365 */, count(*) cnt /* 4.077.468.307 */
-- FROM $schema_name.messages;

-- %%
CREATE TABLE IF NOT EXISTS ${schema_name}.sea_zones
USING DELTA LOCATION '/mnt/bd/openuniverselake/aisraw/havplan/delta';

-- %%
/* SET spark.databricks.geo.enabled = true; */

SELECT *, ST_GeomFromWKT(geometry) FROM ${schema_name}.sea_zones
