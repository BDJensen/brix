# %%
# %sql
create function utl.my_function(a int) returns int return a + 42;

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType

def answer(q):
    return 42;

#my_answer = udf(answer, StringType())

spark.udf.register("utl.answer", answer, StringType())
