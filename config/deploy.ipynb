# %%
dbutils.notebook.run("../database/create_schema", 60, {"schema_name": "vessel"})  
dbutils.notebook.run("../database/create_views", 120, {"schema_name": "vessel"}) 
dbutils.notebook.run("../database/create_tables", 120, {"schema_name": "vessel"})   
dbutils.notebook.run("../transforms/create_text", 120, {"schema_name": "vessel"})
